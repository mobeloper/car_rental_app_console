# %% [markdown]
# ## Online Car Rental Platform
#
# #### Caltech AI & Machine Learning Bootcamp
# #### Batch 2 - Jan 2024
#
# #### Course 2 Project: CB AIML Foundations: Programming Refresher
# #### By: Eric Michel
# #### Date: Feb 3, 2024
#
# Problem Statement:
#
# A car rental company has requested you to develop an online platform for renting cars where customers can easily view the cars available for rental on an hourly, daily, or weekly basis. The company will show the current inventory and verify requests by checking the available stock. Upon returning the car, customers will receive an automatically generated bill.
#
# For simplicity, let’s assume that:
# 1.    Customers may rent cars using one of the following options: hourly, daily, or weekly rental.
# 2.    Customers can freely choose the number of cars they wish to rent as long as the quantity of available cars exceeds their requested amount.

# %%
#Main Project File

# Import the car rental module
from CarRental import CarRental

RentCarApp = CarRental()


# Main method
def main():

    #Initialize the app with initial configurations
    RentCarApp.start()  # Add 10 cars to Car object

    #Run the App
    running=True
    while running==True:
        user_selection = RentCarApp.main_menu()

        # Methods for display available cars, requesting the cars and returning them
        #receive the customer's input to choose between displaying car availability, 
        #rental modes, or returning the cars
        if user_selection==0:
            print("Thank you.\nSee you next time!")
            running=False
        elif user_selection==1:
            RentCarApp.get_available_cars()
        elif user_selection==2:
            rentedCar = RentCarApp.rent_car()
        elif user_selection==3:
            RentCarApp.return_car()


if __name__ == "__main__":

    # Run the main method to start project
    main()
# Out:
# 10  cars created succesfully.
#  HOW CAN WE SERVE YOU?:
#           1 - See Available Cars
#           2 - Rent Car
#           3 - Return Car
#
#         * Type '0' to Terminate App.
#
# Avalable cars:  10
#
#                 ID=1101
#                 Maker: TOYOTA
#                 Year: 2020
#                 Name: TRAVA
#                 Plate: fo393j
#                 Color: red
#                 Style: sports
#                 Version: standard
#                 Engine: gas
#                 Doors: 4
#                 Passengers: 2
#                 ==
#                 status: available
#                 times rented: never
#                 pricing (hourly,daily,weekly): $[60, 300, 1500] USD
#
#
#                 ID=1102
#                 Maker: HYUNDAI
#                 Year: 2021
#                 Name: BOOY
#                 Plate: 483h42
#                 Color: silver
#                 Style: SUV
#                 Version: basic
#                 Engine: hydrogen
# ...
